# %% [markdown]
#  # Introduction

# %% [markdown]
# Brazilian e-commerce has been growing rapidly in recent years, with a wide variety of products and services available to consumers. One of the companies that has contributed to this growth is Olist, which offers an e-commerce platform for small and medium-sized Brazilian companies to sell their products online.
#
# Olist connects these companies to a wide network of marketplaces such as Mercado Livre, B2W, and Amazon, allowing them to reach a larger customer base and increase their sales. In addition, the company offers a set of tools to help companies manage their orders, payments, and deliveries.
#
# This Data Science project is divided into three parts. The first part is about understanding the business and the data using SQL, where we explore the "Brazilian E-Commerce Public Dataset by Olist" to better understand how the company works and what information is available.
#
# In the [second part](https://www.kaggle.com/code/gustavofelici/1-understanding-business-and-data-using-sql/notebookhttps://www.kaggle.com/code/gustavofelici/1-understanding-business-and-data-using-sql/), we focused on data manipulation and visualization, where we cleaned and organized the dataset and created visualizations to better understand the relationships between the variables.
#
# Finally, in the third part of the project, our goal is to predict customer satisfaction based on the review score using machine learning models. With this prediction, the company will be able to identify areas for improvement in its platform and offer an even better service to its customers.
#
# I would like to thank Olist for making the "Brazilian E-Commerce Public Dataset by Olist" available and for allowing the data scientist community to explore and better understand the workings of their e-commerce platform.
#
# I am available to answer any questions or comments about this project. I hope that this work can contribute to a better understanding of the customer experience in Brazilian e-commerce and to the continuous improvement of the services offered by Olist.

# %% [markdown]
# ## Data Base Schema

# %% [markdown]
# ![Data Base.png](data:image/png;base64,...)

# %% [markdown]
# # Data Understanding

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# # Create SQL Engine

# %%
## Import libraries to establish a connection to MySQL server
import sqlite3
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo = False)

# %%
# Import data to dataframes
# linked with 'order_id', 'customer_id'
path = '/content/drive/MyDrive/Data Science/Projects/Olist/Input'
orders = pd.read_csv(f'{path}/olist_orders_dataset.csv')

# linked with 'order_id'
order_payments = pd.read_csv(f'{path}/olist_order_payments_dataset.csv')
order_reviews = pd.read_csv(f'{path}/olist_order_reviews_dataset.csv')

# linked with 'order_id', 'product_id', 'seller_id'
order_items = pd.read_csv(f'{path}/olist_order_items_dataset.csv')

# linked with 'product_id'
products = pd.read_csv(f'{path}/olist_products_dataset.csv')

# linked with 'seller_id', 'zip_cod_prefix'
sellers = pd.read_csv(f'{path}/olist_sellers_dataset.csv')

# linked with 'customer_id', 'zip_code_prefix'
customers = pd.read_csv(f'{path}/olist_customers_dataset.csv')

# linked with 'zip_code_prefix'
geolocation = pd.read_csv(f'{path}/olist_geolocation_dataset.csv')

# linked with 'product_category_name'
products_cat_translated = pd.read_csv(f'{path}/product_category_name_translation.csv')

# %%
# export dataframes to database

orders.to_sql(name = 'Orders', con = engine)
order_payments.to_sql(name = 'OrderPayment', con = engine)
order_reviews.to_sql(name = 'OrderReview', con = engine)
order_items.to_sql(name = 'OrderItem', con = engine)

products.to_sql(name = 'Product', con = engine)
products_cat_translated.to_sql(name = 'products_cat_translated', con = engine)
sellers.to_sql(name = 'Seller', con = engine)
customers.to_sql(name = 'Customer', con = engine)

geolocation.to_sql(name = 'Geolocation', con = engine)

# %%
get_order_value = """
SELECT Orders.order_id, Orders.order_purchase_timestamp, OrderItem.price, OrderItem.freight_value 
FROM Orders JOIN OrderItem 
ON Orders.order_id = OrderItem.order_id;
"""
results = pd.read_sql_query(get_order_value,engine)

column = ['order_id','order_purchase_timestamp','price','freight_value']
df_Order_value = pd.DataFrame(results,columns=column)

# %% [markdown]
# ## SQL

# %%
def get_query(query): 
  return pd.read_sql_query(query,engine)

features_query = {}

# %% [markdown]
# # Orders

# %%
query = """
SELECT *
FROM Orders;
"""
get_query(query)
# Out:
#        index                          order_id  \
# 0          0  e481f51cbdc54678b7cc49136f2d6af7
# 1          1  53cdb2fc8bc7dce0b6741e2150273451
# 2          2  47770eb9100c2d0c44946d9cf07ec65d
# 3          3  949d5b44dbf5de918fe9c16f97b45f8a
# 4          4  ad21c59c0840e6cb83a9ceb5573f8159
# ...      ...                               ...
# 99436  99436  9c5dedf39a927c1b2549525ed64a053c
# 99437  99437  63943bddc261676b46f01ca7ac2f7bd8
# 99438  99438  83c1379a015df1e13d02aae0204711ab
# 99439  99439  11c177c8e97725db2631073c19f07b62
# 99440  99440  66dea50a8b16d9b4dee7af250b4be1a5
#
#                             customer_id order_status order_purchase_timestamp  \
# 0      9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1      b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2      41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# 3      f88197465ea7920adcdbec7375364d82    delivered      2017-11-18 19:28:06
# 4      8ab97904e6daea8866dbdbc4fb7aad2c    delivered      2018-02-13 21:18:39
# ...                                 ...          ...                      ...
# 99436  39bd1228ee8140590ac3aca26f2dfe00    delivered      2017-03-09 09:54:05
# 99437  1fca14ff2861355f6e5f14306ff977a7    delivered      2018-02-06 12:58:58
# 99438  1aa71eb042121263aafbe80c1b562c9c    delivered      2017-08-27 14:46:43
# 99439  b331b74b18dc79bcdf6532d51e1637c1    delivered      2018-01-08 21:28:27
# 99440  edb027a75a1449115f6b43211ae02a24    delivered      2018-03-08 20:57:30
#
#          order_approved_at order_delivered_carrier_date  \
# 0      2017-10-02 11:07:15          2017-10-04 19:55:00
# 1      2018-07-26 03:24:27          2018-07-26 14:31:00
# 2      2018-08-08 08:55:23          2018-08-08 13:50:00
# 3      2017-11-18 19:45:59          2017-11-22 13:39:59
# 4      2018-02-13 22:20:29          2018-02-14 19:46:34
# ...                    ...                          ...
# 99436  2017-03-09 09:54:05          2017-03-10 11:18:03
# 99437  2018-02-06 13:10:37          2018-02-07 23:22:42
# 99438  2017-08-27 15:04:16          2017-08-28 20:52:26
# 99439  2018-01-08 21:36:21          2018-01-12 15:35:03
# 99440  2018-03-09 11:20:28          2018-03-09 22:11:59
#
#       order_delivered_customer_date order_estimated_delivery_date
# 0               2017-10-10 21:25:13           2017-10-18 00:00:00
# 1               2018-08-07 15:27:45           2018-08-13 00:00:00
# 2               2018-08-17 18:06:29           2018-09-04 00:00:00
# 3               2017-12-02 00:28:42           2017-12-15 00:00:00
# 4               2018-02-16 18:17:02           2018-02-26 00:00:00
# ...                             ...                           ...
# 99436           2017-03-17 15:08:01           2017-03-28 00:00:00
# 99437           2018-02-28 17:37:56           2018-03-02 00:00:00
# 99438           2017-09-21 11:24:17           2017-09-27 00:00:00
# 99439           2018-01-25 23:32:54           2018-02-15 00:00:00
# 99440           2018-03-16 13:08:30           2018-04-03 00:00:00
#
# [99441 rows x 9 columns]

# %% [markdown]
# ## What `order_status` exist?

# %%
query = """
SELECT DISTINCT(order_status)
FROM Orders;
"""
get_query(query)
# Out:
#   order_status
# 0    delivered
# 1     invoiced
# 2      shipped
# 3   processing
# 4  unavailable
# 5     canceled
# 6      created
# 7     approved

# %% [markdown]
# Seven Types

# %% [markdown]
# ## Does a `customer_id` have multiple `orders_id`?

# %%
query = """
SELECT customer_id, COUNT(order_id) as order_count
FROM Orders
WHERE order_status == 'delivered'
GROUP BY customer_id
ORDER BY 2 DESC
;
"""
get_query(query)
# Out:
#                             customer_id  order_count
# 0      ffffa3172527f765de70084a7e53aae8            1
# 1      ffff42319e9b2d713724ae527742af25            1
# 2      fffeda5b6d849fbd39689bb92087f431            1
# 3      fffecc9f79fd8c764f843e9951b11341            1
# 4      fffcb937e9dd47a13f05ecb8290f4d3e            1
# ...                                 ...          ...
# 96473  000379cdec625522490c315e70c7a9fb            1
# 96474  0002414f95344307404f0ace7a26f1d5            1
# 96475  0001fd6190edaaf884bcaf3d49edf079            1
# 96476  000161a058600d5901f007fab4c27140            1
# 96477  00012a2ce6f8dcda20d059ce98491703            1
#
# [96478 rows x 2 columns]

# %% [markdown]
# Each `customer_id` has one `order_id`

# %% [markdown]
# ## What is the date range of the orders?
# I want to understand the volume of my data over time using `order_purchase_timestamp`

# %%
query = """
SELECT order_status, COUNT(order_id)
FROM Orders
GROUP BY order_status
ORDER BY order_purchase_timestamp DESC
;
"""
get_query(query)
# Out:
#   order_status  COUNT(order_id)
# 0     canceled              625
# 1      shipped             1107
# 2      created                5
# 3  unavailable              609
# 4    delivered            96478
# 5   processing              301
# 6     invoiced              314
# 7     approved                2

# %% [markdown]
# Most of the values are concentrated in the delivered, while the rest is unbalanced, this can occur because the statuses have an execution order and generate the log from the timestamps that the table has, so probably we will only work with the `delivered` orders because that is where the data tends to be complete

# %%
query = """
SELECT order_id,order_status,  order_purchase_timestamp
FROM Orders
ORDER BY order_purchase_timestamp DESC
;
"""
get_query(query)
# Out:
#                                order_id order_status order_purchase_timestamp
# 0      10a045cdf6a5650c21e9cfeb60384c16     canceled      2018-10-17 17:30:18
# 1      b059ee4de278302d550a3035c4cdb740     canceled      2018-10-16 20:16:02
# 2      a2ac6dad85cf8af5b0afb510a240fe8c     canceled      2018-10-03 18:55:29
# 3      616fa7d4871b87832197b2a137a115d2     canceled      2018-10-01 15:30:09
# 4      392ed9afd714e3c74767d0c4d3e3f477     canceled      2018-09-29 09:13:03
# ...                                 ...          ...                      ...
# 99436  71303d7e93b399f5bcd537d124c0bcfa     canceled      2016-10-02 22:07:52
# 99437  bfbd0f9bdef84302105ad712db648a6c    delivered      2016-09-15 12:16:38
# 99438  809a282bbd5dbcabb6f2f724fca862ec     canceled      2016-09-13 15:24:19
# 99439  e5fa5a7210941f7d56d0208e4e071d35     canceled      2016-09-05 00:15:34
# 99440  2e7a8482f6fb09756ca50c10d7bfc047      shipped      2016-09-04 21:15:19
#
# [99441 rows x 3 columns]

# %% [markdown]
# The Date Range is from 2018-10-17 to 2016-09-04

# %% [markdown]
# ## Time difference between some features
# Let's visualize it to understand

# %% [markdown]
# How many days was it?
# * `buy_to_approved`: From purchase to approval
# * `aproved_to_carrier`: From approval to carrier
# * `carrier_to_delivered`: From carrier to delivered
# * `carrier_to_customer`: From carrier to customer
# * `estimated`: From (carrier to customer) to (carrier to estimated)

# %%
query = """
SELECT order_id, customer_id, order_status,
ROUND(JULIANDAY(order_approved_at) - JULIANDAY(order_purchase_timestamp)) AS buy_to_approved,
ROUND(JULIANDAY(order_delivered_carrier_date	) - JULIANDAY(order_approved_at)) AS aproved_to_carrier,
ROUND(JULIANDAY(order_estimated_delivery_date	) - JULIANDAY(order_delivered_carrier_date)) AS carrier_to_delivered,
ROUND(JULIANDAY(order_delivered_customer_date	) - JULIANDAY(order_delivered_carrier_date)) AS carrier_to_customer,
( ROUND(JULIANDAY(order_delivered_customer_date	) - JULIANDAY(order_delivered_carrier_date)) - ROUND(JULIANDAY(order_estimated_delivery_date	) - JULIANDAY(order_delivered_carrier_date))) AS estimated
FROM Orders
;
"""

date_features = get_query(query)
date_features
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status  buy_to_approved  aproved_to_carrier  carrier_to_delivered  \
# 0        delivered              0.0                 2.0                  13.0
# 1        delivered              1.0                 0.0                  17.0
# 2        delivered              0.0                 0.0                  26.0
# 3        delivered              0.0                 4.0                  22.0
# 4        delivered              0.0                 1.0                  11.0
# ...            ...              ...                 ...                   ...
# 99436    delivered              0.0                 1.0                  18.0
# 99437    delivered              0.0                 1.0                  22.0
# 99438    delivered              0.0                 1.0                  29.0
# 99439    delivered              0.0                 4.0                  33.0
# 99440    delivered              1.0                 0.0                  24.0
#
#        carrier_to_customer  estimated
# 0                      6.0       -7.0
# 1                     12.0       -5.0
# 2                      9.0      -17.0
# 3                      9.0      -13.0
# 4                      2.0       -9.0
# ...                    ...        ...
# 99436                  7.0      -11.0
# 99437                 21.0       -1.0
# 99438                 24.0       -5.0
# 99439                 13.0      -20.0
# 99440                  7.0      -17.0
#
# [99441 rows x 8 columns]

# %%
time_features = ['buy_to_approved', 'aproved_to_carrier', 'carrier_to_delivered', 'carrier_to_customer', 'estimated']

# %%
plt.figure(figsize=(20,4))
fig, ax = plt.subplots(ncols=len(time_features), figsize=(20,6))
i=0
for feature in time_features:
  sns.boxplot(y=date_features[feature], ax=ax[i])
  i+=1

# %% [markdown]
# It is better to do this date analysis inside python to use a calendar library to have more precise date ranges, but from this visualization we already have an idea.

# %% [markdown]
# ## Final Query
# Query with all useful members just to make it easier to find them without having to type so much

# %%
query = """
SELECT 
  *
FROM Orders
;
"""

features_query['Orders'] = query
get_query(features_query['Orders'])
# Out:
#        index                          order_id  \
# 0          0  e481f51cbdc54678b7cc49136f2d6af7
# 1          1  53cdb2fc8bc7dce0b6741e2150273451
# 2          2  47770eb9100c2d0c44946d9cf07ec65d
# 3          3  949d5b44dbf5de918fe9c16f97b45f8a
# 4          4  ad21c59c0840e6cb83a9ceb5573f8159
# ...      ...                               ...
# 99436  99436  9c5dedf39a927c1b2549525ed64a053c
# 99437  99437  63943bddc261676b46f01ca7ac2f7bd8
# 99438  99438  83c1379a015df1e13d02aae0204711ab
# 99439  99439  11c177c8e97725db2631073c19f07b62
# 99440  99440  66dea50a8b16d9b4dee7af250b4be1a5
#
#                             customer_id order_status order_purchase_timestamp  \
# 0      9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1      b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2      41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# 3      f88197465ea7920adcdbec7375364d82    delivered      2017-11-18 19:28:06
# 4      8ab97904e6daea8866dbdbc4fb7aad2c    delivered      2018-02-13 21:18:39
# ...                                 ...          ...                      ...
# 99436  39bd1228ee8140590ac3aca26f2dfe00    delivered      2017-03-09 09:54:05
# 99437  1fca14ff2861355f6e5f14306ff977a7    delivered      2018-02-06 12:58:58
# 99438  1aa71eb042121263aafbe80c1b562c9c    delivered      2017-08-27 14:46:43
# 99439  b331b74b18dc79bcdf6532d51e1637c1    delivered      2018-01-08 21:28:27
# 99440  edb027a75a1449115f6b43211ae02a24    delivered      2018-03-08 20:57:30
#
#          order_approved_at order_delivered_carrier_date  \
# 0      2017-10-02 11:07:15          2017-10-04 19:55:00
# 1      2018-07-26 03:24:27          2018-07-26 14:31:00
# 2      2018-08-08 08:55:23          2018-08-08 13:50:00
# 3      2017-11-18 19:45:59          2017-11-22 13:39:59
# 4      2018-02-13 22:20:29          2018-02-14 19:46:34
# ...                    ...                          ...
# 99436  2017-03-09 09:54:05          2017-03-10 11:18:03
# 99437  2018-02-06 13:10:37          2018-02-07 23:22:42
# 99438  2017-08-27 15:04:16          2017-08-28 20:52:26
# 99439  2018-01-08 21:36:21          2018-01-12 15:35:03
# 99440  2018-03-09 11:20:28          2018-03-09 22:11:59
#
#       order_delivered_customer_date order_estimated_delivery_date
# 0               2017-10-10 21:25:13           2017-10-18 00:00:00
# 1               2018-08-07 15:27:45           2018-08-13 00:00:00
# 2               2018-08-17 18:06:29           2018-09-04 00:00:00
# 3               2017-12-02 00:28:42           2017-12-15 00:00:00
# 4               2018-02-16 18:17:02           2018-02-26 00:00:00
# ...                             ...                           ...
# 99436           2017-03-17 15:08:01           2017-03-28 00:00:00
# 99437           2018-02-28 17:37:56           2018-03-02 00:00:00
# 99438           2017-09-21 11:24:17           2017-09-27 00:00:00
# 99439           2018-01-25 23:32:54           2018-02-15 00:00:00
# 99440           2018-03-16 13:08:30           2018-04-03 00:00:00
#
# [99441 rows x 9 columns]

# %% [markdown]
# # Order Payment

# %%
query = """
SELECT *
FROM OrderPayment
;
"""
get_query(query)
# Out:
#          index                          order_id  payment_sequential  \
# 0            0  b81ef226f3fe1789b1e8b2acac839d17                   1
# 1            1  a9810da82917af2d9aefd1278f1dcfa0                   1
# 2            2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1
# 3            3  ba78997921bbcdc1373bb41e913ab953                   1
# 4            4  42fdf880ba16b47b59251dd489d4441a                   1
# ...        ...                               ...                 ...
# 103881  103881  0406037ad97740d563a178ecc7a2075c                   1
# 103882  103882  7b905861d7c825891d6347454ea7863f                   1
# 103883  103883  32609bbb3dd69b3c066a6860554a77bf                   1
# 103884  103884  b8b61059626efa996a60be9bb9320e10                   1
# 103885  103885  28bbae6599b09d39ca406b747b6632b1                   1
#
#        payment_type  payment_installments  payment_value
# 0       credit_card                     8          99.33
# 1       credit_card                     1          24.39
# 2       credit_card                     1          65.71
# 3       credit_card                     8         107.78
# 4       credit_card                     2         128.45
# ...             ...                   ...            ...
# 103881       boleto                     1         363.31
# 103882  credit_card                     2          96.80
# 103883  credit_card                     1          47.77
# 103884  credit_card                     5         369.54
# 103885       boleto                     1         191.58
#
# [103886 rows x 6 columns]

# %% [markdown]
# ## Exploring the columns...

# %% [markdown]
# ### `payment_sequential`

# %%
query = """
SELECT payment_sequential, COUNT(order_id), AVG(payment_value)
FROM OrderPayment
GROUP BY payment_sequential
ORDER BY 2 DESC, 1
;
"""
get_query(query)
# Out:
#     payment_sequential  COUNT(order_id)  AVG(payment_value)
# 0                    1            99360          158.336774
# 1                    2             3039           79.101849
# 2                    3              581           30.417711
# 3                    4              278           23.265432
# 4                    5              170           23.895882
# 5                    6              118           24.061610
# 6                    7               82           20.672439
# 7                    8               54           13.437407
# 8                    9               43           13.521628
# 9                   10               34           15.617353
# 10                  11               29           13.351379
# 11                  12               21           16.077619
# 12                  13               13            8.773846
# 13                  14               10           13.481000
# 14                  15                8           12.435000
# 15                  16                6            8.106667
# 16                  17                6            6.243333
# 17                  18                6            3.098333
# 18                  19                6            3.486667
# 19                  20                4           39.172500
# 20                  21                4            2.230000
# 21                  22                3            2.046667
# 22                  23                2            9.945000
# 23                  24                2            1.605000
# 24                  25                2            2.605000
# 25                  26                2           25.685000
# 26                  27                1           66.020000
# 27                  28                1           29.050000
# 28                  29                1           19.260000

# %% [markdown]
# It looks like something like payment attempts because the quantity is decreasing and a `payment_sequence` has a relation of many to an `order_id`, so I don't believe it is something like installments because the order_id volume decreases a lot after the first one

# %% [markdown]
# ### `payment_type`

# %%
query = """
SELECT payment_type, COUNT(order_id), AVG(payment_value)
FROM OrderPayment
GROUP BY payment_type
ORDER BY 2 DESC
;
"""
get_query(query)
# Out:
#   payment_type  COUNT(order_id)  AVG(payment_value)
# 0  credit_card            76795          163.319021
# 1       boleto            19784          145.034435
# 2      voucher             5775           65.703354
# 3   debit_card             1529          142.570170
# 4  not_defined                3            0.000000

# %% [markdown]
# ####  Let's take a look at payment_type to see if it can change according to payment_sequential

# %%
query = """
SELECT order_id, payment_sequential, payment_type, payment_value
FROM OrderPayment
WHERE payment_sequential = 18
;
"""
get_query(query).head(1)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  285c2e15bebd4ac83635ccc563dc71f4                  18      voucher
#
#    payment_value
# 0            1.7

# %% [markdown]
# Escolhido: `285c2e15bebd4ac83635ccc563dc71f4`

# %%
query = """
SELECT payment_sequential, payment_type, payment_installments,  payment_value
FROM OrderPayment
WHERE order_id = '285c2e15bebd4ac83635ccc563dc71f4'
ORDER BY payment_sequential ASC
;
"""
get_query(query)
# Out:
#     payment_sequential payment_type  payment_installments  payment_value
# 0                    1  credit_card                     1           1.62
# 1                    2      voucher                     1           1.24
# 2                    3      voucher                     1           1.40
# 3                    4      voucher                     1           2.89
# 4                    5      voucher                     1           1.75
# 5                    6      voucher                     1           2.85
# 6                    7      voucher                     1           1.14
# 7                    8      voucher                     1           1.23
# 8                    9      voucher                     1           1.05
# 9                   10      voucher                     1           2.78
# 10                  11      voucher                     1           1.03
# 11                  12      voucher                     1           2.24
# 12                  13      voucher                     1           4.07
# 13                  14      voucher                     1           1.75
# 14                  15      voucher                     1           2.70
# 15                  16      voucher                     1           1.96
# 16                  17      voucher                     1           1.23
# 17                  18      voucher                     1           1.70
# 18                  19      voucher                     1           1.00
# 19                  20      voucher                     1           1.09
# 20                  21      voucher                     1           3.08
# 21                  22      voucher                     1           1.05

# %% [markdown]
# Ok, the payment_type can change and the payment values change too, apparently it is some kind of error in the payment itself, the values vary in a way that I don't see much sense, but it is not a big variation

# %% [markdown]
# ### `payment_installments`

# %%
query = """
SELECT payment_installments, COUNT(order_id), AVG(payment_value)
FROM OrderPayment
GROUP BY payment_installments
ORDER BY 1 ASC, 2 DESC
;
"""
get_query(query)
# Out:
#     payment_installments  COUNT(order_id)  AVG(payment_value)
# 0                      0                2           94.315000
# 1                      1            52546          112.420229
# 2                      2            12413          127.228150
# 3                      3            10461          142.539317
# 4                      4             7098          163.976840
# 5                      5             5239          183.465222
# 6                      6             3920          209.849952
# 7                      7             1626          187.673672
# 8                      8             4268          307.737427
# 9                      9              644          203.440870
# 10                    10             5328          415.085837
# 11                    11               23          124.932174
# 12                    12              133          321.678496
# 13                    13               16          150.462500
# 14                    14               15          167.962667
# 15                    15               74          445.553108
# 16                    16                5          292.694000
# 17                    17                8          174.602500
# 18                    18               27          486.483333
# 19                    20               17          615.801765
# 20                    21                3          243.700000
# 21                    22                1          228.710000
# 22                    23                1          236.480000
# 23                    24               18          610.048889

# %% [markdown]
# I'm not sure what it means, but it seems to be some kind of payment problem, but I'm not sure because most of the data is not concentrated in any of these `payment_installments`

# %% [markdown]
# ## Final Query
# This is how I will analyze this data for each order

# %%
query = """
SELECT 
  order_id, 
  MAX(payment_sequential) as payment_sequential, 
  MAX(payment_type) as payment_type, 
  MAX(payment_installments) as payment_installments, 
  AVG(payment_value) as avg_payment_value
FROM OrderPayment
GROUP BY order_id
;
"""
features_query['OrderPayment'] = query
get_query(query)
# Out:
#                                order_id  payment_sequential payment_type  \
# 0      00010242fe8c5a6d1ba2dd792cb16214                   1  credit_card
# 1      00018f77f2f0320c557190d7a144bdd3                   1  credit_card
# 2      000229ec398224ef6ca0657da4fc703e                   1  credit_card
# 3      00024acbcdf0a6daa1e931b038114c75                   1  credit_card
# 4      00042b26cf59d7ce69dfabb4e55b4fd9                   1  credit_card
# ...                                 ...                 ...          ...
# 99435  fffc94f6ce00a00581880bf54a75a037                   1       boleto
# 99436  fffcd46ef2263f404302a634eb57f7eb                   1       boleto
# 99437  fffce4705a9662cd70adb13d4a31832d                   1  credit_card
# 99438  fffe18544ffabc95dfada21779c9644f                   1  credit_card
# 99439  fffe41c64501cc87c801fd61db3f6244                   1  credit_card
#
#        payment_installments  avg_payment_value
# 0                         2              72.19
# 1                         3             259.83
# 2                         5             216.87
# 3                         2              25.78
# 4                         3             218.04
# ...                     ...                ...
# 99435                     1             343.40
# 99436                     1             386.53
# 99437                     3             116.85
# 99438                     3              64.71
# 99439                     1              55.79
#
# [99440 rows x 5 columns]

# %% [markdown]
# # Order Review

# %%
query = """
SELECT *
FROM OrderReview;
"""
get_query(query)
# Out:
#        index                         review_id  \
# 0          0  7bc2406110b926393aa56f80a40eba40
# 1          1  80e641a11e56f04c1ad469d5645fdfde
# 2          2  228ce5500dc1d8e020d8d1322874b6f0
# 3          3  e64fb393e7b32834bb789ff8bb30750e
# 4          4  f7c4243c7fe1938f181bec41a392bdeb
# ...      ...                               ...
# 99219  99219  574ed12dd733e5fa530cfd4bbf39d7c9
# 99220  99220  f3897127253a9592a73be9bdfdf4ed7a
# 99221  99221  b3de70c89b1510c4cd3d0649fd302472
# 99222  99222  1adeb9d84d72fe4e337617733eb85149
# 99223  99223  efe49f1d6f951dd88b51e6ccd4cc548f
#
#                                order_id  review_score review_comment_title  \
# 0      73fc7af87114b39712e6da79b0a377eb             4                 None
# 1      a548910a1c6147796b98fdf73dbeba33             5                 None
# 2      f9e4b658b201a9f2ecdecbb34bed034b             5                 None
# 3      658677c97b385a9be170737859d3511b             5                 None
# 4      8e6bfb81e283fa7e4f11123a3fb894f1             5                 None
# ...                                 ...           ...                  ...
# 99219  2a8c23fee101d4d5662fa670396eb8da             5                 None
# 99220  22ec9f0669f784db00fa86d035cf8602             5                 None
# 99221  55d4004744368f5571d1f590031933e4             5                 None
# 99222  7725825d039fc1f0ceb7635e3f7d9206             4                 None
# 99223  90531360ecb1eec2a1fbb265a0db0508             1                 None
#
#                                   review_comment_message review_creation_date  \
# 0                                                   None  2018-01-18 00:00:00
# 1                                                   None  2018-03-10 00:00:00
# 2                                                   None  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                               None  2018-07-07 00:00:00
# 99220                                               None  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                               None  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [99224 rows x 8 columns]

# %% [markdown]
# ## How many reviews does an order have?
# One to one or many to one

# %%
query = """
SELECT order_id, COUNT(review_id), MAX(review_creation_date), AVG(review_score)
FROM OrderReview
GROUP BY order_id
HAVING COUNT(review_id) > 1
ORDER BY MAX(review_creation_date) DESC

;
"""
get_query(query)
# Out:
#                              order_id  COUNT(review_id)  \
# 0    f3ee55bf50ef2f2318599425ef80107d                 2
# 1    dab8a6c6bd6ec448df5b3a6b6cb887bc                 2
# 2    84aa61a900410cfe26b57337d376a1ae                 2
# 3    80fe5b2fe4869330fabbceea5e5e7c0c                 2
# 4    3e93213bb8fdda91186b4018b2fe0030                 2
# ..                                ...               ...
# 542  566f53fc7d36fa366f7e221468121877                 2
# 543  2a3d67c0d2045bf67abb3d8f320ac29f                 2
# 544  b6e5aa946acc4e29e7069510f28a0bce                 2
# 545  c4f710df20f7d1500da1aef81a993f65                 2
# 546  b19169c7cb8391fb8561e094d61c531a                 2
#
#     MAX(review_creation_date)  AVG(review_score)
# 0         2018-08-29 00:00:00                4.5
# 1         2018-08-22 00:00:00                3.5
# 2         2018-08-22 00:00:00                5.0
# 3         2018-08-11 00:00:00                5.0
# 4         2018-08-08 00:00:00                5.0
# ..                        ...                ...
# 542       2017-02-08 00:00:00                5.0
# 543       2017-01-31 00:00:00                5.0
# 544       2017-01-29 00:00:00                5.0
# 545       2016-10-29 00:00:00                5.0
# 546       2016-10-29 00:00:00                5.0
#
# [547 rows x 4 columns]

# %% [markdown]
# There is one order for several reviews, but there are few cases that this happens, only 547 times, and they are cases where an order has two reviews

# %% [markdown]
# Of these small cases of more than one review, let's look at how they work

# %%
query = """
SELECT *
FROM OrderReview
WHERE order_id = '03c939fd7fd3b38f8485a0f95798f1f6'
ORDER BY review_answer_timestamp ASC
;
"""
get_query(query).head()
# Out:
#    index                         review_id                          order_id  \
# 0  69438  405eb2ea45e1dbe2662541ae5b47e2aa  03c939fd7fd3b38f8485a0f95798f1f6
# 1   8273  b04ed893318da5b863e878cd3d0511df  03c939fd7fd3b38f8485a0f95798f1f6
# 2  51527  f4bb9d6dd4fb6dcc2298f0e7b17b8e1e  03c939fd7fd3b38f8485a0f95798f1f6
#
#    review_score review_comment_title  \
# 0             3                 None
# 1             3                 None
# 2             4                 None
#
#                               review_comment_message review_creation_date  \
# 0  Seria ótimo se tivesem entregue os 3 (três) pe...  2018-03-06 00:00:00
# 1  Um ponto negativo que achei foi a cobrança de ...  2018-03-20 00:00:00
# 2                                               None  2018-03-29 00:00:00
#
#   review_answer_timestamp
# 0     2018-03-06 19:50:32
# 1     2018-03-21 02:28:23
# 2     2018-03-30 00:29:09

# %% [markdown]
# I looked at some of these cases, the variation between the scores was not big, nobody gave 1 after 5, what will make more sense in these cases is to use the max value to maintain the standard of the score

# %% [markdown]
# ## Negative Comments

# %%
query = """
SELECT review_comment_title,review_comment_message, review_creation_date	
FROM OrderReview
WHERE review_score = 1
ORDER BY review_creation_date DESC
;
"""
get_query(query)
# Out:
#          review_comment_title  \
# 0       Informação\preocupada
# 1                        None
# 2      Não recebi meu produto
# 3       Vcs precisam melhorar
# 4            Muito frágil !!!
# ...                       ...
# 11419                    None
# 11420                    None
# 11421                    None
# 11422                    None
# 11423                    None
#
#                                   review_comment_message review_creation_date
# 0      Minha avaliação ta sendo esta pq aqui aparece ...  2018-08-31 00:00:00
# 1                                                   None  2018-08-31 00:00:00
# 2      Não recebi meu produto e ainda não respondem m...  2018-08-31 00:00:00
# 3      O pedido se tratava de 5 frascos de oleo de li...  2018-08-31 00:00:00
# 4      Achei o produto muito pequeno e onde fica a "t...  2018-08-31 00:00:00
# ...                                                  ...                  ...
# 11419  Produto não foi entregue. Não foi enviada nota...  2016-10-20 00:00:00
# 11420  Comprei uma capa para um tablet e a que foi en...  2016-10-20 00:00:00
# 11421  PRODUTO NÃO CHEGOU,E JÁ PASSOU O PRAZO DE ENTREGA  2016-10-09 00:00:00
# 11422     nao recebi o produto e nem resposta da empresa  2016-10-06 00:00:00
# 11423  MEU PEDIDO NÃO FOI ENTREGUE E NÃO FOI DADA NEN...  2016-10-02 00:00:00
#
# [11424 rows x 3 columns]

# %% [markdown]
# ## Score
# How many reviews per score?

# %%
query = """
SELECT review_score, COUNT(review_id)
FROM OrderReview
GROUP BY review_score
;
"""
get_query(query)
# Out:
#    review_score  COUNT(review_id)
# 0             1             11424
# 1             2              3151
# 2             3              8179
# 3             4             19142
# 4             5             57328

# %% [markdown]
# ## How many people put title in the review?
# `review_comment_title`
# 1. Do people not put in a date because of some update that occurred in the system? If yes, from some point in time this happened or stopped happening

# %%
query = """
SELECT review_comment_title, review_creation_date

FROM OrderReview
WHERE review_comment_title IS NOT NULL
ORDER BY review_creation_date DESC
;
"""
get_query(query)
# Out:
#          review_comment_title review_creation_date
# 0        Entrega de encomenda  2018-08-31 00:00:00
# 1             capa de notbuk   2018-08-31 00:00:00
# 2                       Ótimo  2018-08-31 00:00:00
# 3                       Ótimo  2018-08-31 00:00:00
# 4                       Ótima  2018-08-31 00:00:00
# ...                       ...                  ...
# 11563               Recomendo  2017-10-27 00:00:00
# 11564  A câmera não funcionou  2017-09-13 00:00:00
# 11565              Muito bom.  2017-09-01 00:00:00
# 11566                   otimo  2017-06-29 00:00:00
# 11567       super recomendado  2017-05-16 00:00:00
#
# [11568 rows x 2 columns]

# %% [markdown]
# That's right as of 2017-05-16 we started putting titles in the comments

# %%
query = """
SELECT COUNT(review_id)
FROM OrderReview
;
"""
get_query(query)
# Out:
#    COUNT(review_id)
# 0             99224

# %%
str((11568  / 99224) * 100) + ' % of the requests that have a title in the comments'
# Out:
# '11.658469725066515 % of the requests that have a title in the comments'

# %% [markdown]
# ## Final Query

# %%
query = """
SELECT order_id, 
COUNT(review_id), 
MAX(review_score),
CASE WHEN MAX(review_comment_title) IS NULL THEN 0 ELSE 1 END AS has_title,
MAX(review_comment_message),
ROUND(JULIANDAY(MAX(review_answer_timestamp)	) - JULIANDAY(MAX(review_creation_date))) AS create_to_answer

FROM OrderReview
GROUP BY order_id
;
"""
features_query['OrderReview'] = query
get_query(query)
# Out:
#                                order_id  COUNT(review_id)  MAX(review_score)  \
# 0      00010242fe8c5a6d1ba2dd792cb16214                 1                  5
# 1      00018f77f2f0320c557190d7a144bdd3                 1                  4
# 2      000229ec398224ef6ca0657da4fc703e                 1                  5
# 3      00024acbcdf0a6daa1e931b038114c75                 1                  4
# 4      00042b26cf59d7ce69dfabb4e55b4fd9                 1                  5
# ...                                 ...               ...                ...
# 98668  fffc94f6ce00a00581880bf54a75a037                 1                  5
# 98669  fffcd46ef2263f404302a634eb57f7eb                 1                  5
# 98670  fffce4705a9662cd70adb13d4a31832d                 1                  5
# 98671  fffe18544ffabc95dfada21779c9644f                 1                  5
# 98672  fffe41c64501cc87c801fd61db3f6244                 1                  5
#
#        has_title                        MAX(review_comment_message)  \
# 0              0     Perfeito, produto entregue antes do combinado.
# 1              0                                               None
# 2              0  Chegou antes do prazo previsto e o produto sur...
# 3              0                                               None
# 4              0            Gostei pois veio no prazo determinado .
# ...          ...                                                ...
# 98668          0                                               None
# 98669          0                                               None
# 98670          0                                               None
# 98671          0    Recebi o produto antes do prazo e corretamente.
# 98672          0                                               None
#
#        create_to_answer
# 0                   1.0
# 1                   2.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 98668               4.0
# 98669               1.0
# 98670               1.0
# 98671               2.0
# 98672               3.0
#
# [98673 rows x 6 columns]

# %% [markdown]
# # Order Item

# %%
query = """
SELECT *
FROM OrderItem;
"""
get_query(query)
# Out:
#          index                          order_id  order_item_id  \
# 0            0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1            1  00018f77f2f0320c557190d7a144bdd3              1
# 2            2  000229ec398224ef6ca0657da4fc703e              1
# 3            3  00024acbcdf0a6daa1e931b038114c75              1
# 4            4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...        ...                               ...            ...
# 112645  112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
# [112650 rows x 8 columns]

# %% [markdown]
# ## Possible Features
# * `Average price per product`: Average of the product prices in each order, this information as a feature. It can indicate the purchasing power of the customer and the demand for products in different price ranges.
#
# * `Quantity of products per order`: How many products were purchased in each order. Can indicate the customer's level of engagement with your store and their willingness to make larger or smaller purchases.
#
# * `Number of vendors per order`: How many different vendors are involved in each order. It can indicate the diversity of products and the range of options your store offers customers.
#
# * `Average price per salesperson`: Average prices of products sold by each salesperson. It can indicate the quality of products offered by each seller and their reputation on the platform.
#
# * `Shipping limit per merchant`: Each merchant's shipping limit. It can indicate the availability of products in stock and each seller's ability to meet delivery deadlines.
#
# * `Average freight price`: Average freight prices for each order and use this information as a feature. It can indicate the level of customer satisfaction with the cost of delivery and the efficiency of your logistics operation.

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Quantity of items per order

# %%
query = """
SELECT order_id,
COUNT(DISTINCT(product_id)) as count_product,
COUNT(DISTINCT(seller_id)) as count_seller,
MAX(order_item_id) as count_item

FROM OrderItem
GROUP BY order_id
ORDER BY 3 DESC
;
"""
get_query(query)
# Out:
#                                order_id  count_product  count_seller  \
# 0      cf5c8d9f52807cb2d2f0a0ff54c478da              6             5
# 1      1c11d0f4353b31ac3417fbfa5f0f2a8a              6             5
# 2      91be51c856a90d7efe86cf9d082d6ae3              4             4
# 3      8c2b13adf3f377c8f2b06b04321b0925              4             4
# 4      1d23106803c48c391366ff224513fb7f              4             4
# ...                                 ...            ...           ...
# 98661  00042b26cf59d7ce69dfabb4e55b4fd9              1             1
# 98662  00024acbcdf0a6daa1e931b038114c75              1             1
# 98663  000229ec398224ef6ca0657da4fc703e              1             1
# 98664  00018f77f2f0320c557190d7a144bdd3              1             1
# 98665  00010242fe8c5a6d1ba2dd792cb16214              1             1
#
#        count_item
# 0               6
# 1               7
# 2               4
# 3               4
# 4               4
# ...           ...
# 98661           1
# 98662           1
# 98663           1
# 98664           1
# 98665           1
#
# [98666 rows x 4 columns]

# %% [markdown]
# Looking at one order
# `cf5c8d9f52807cb2d2f0a0ff54c478da`

# %%
query = """
SELECT *
FROM OrderItem
WHERE order_id = 'cf5c8d9f52807cb2d2f0a0ff54c478da'
;
"""
get_query(query)
# Out:
#    index                          order_id  order_item_id  \
# 0  91379  cf5c8d9f52807cb2d2f0a0ff54c478da              1
# 1  91380  cf5c8d9f52807cb2d2f0a0ff54c478da              2
# 2  91381  cf5c8d9f52807cb2d2f0a0ff54c478da              3
# 3  91382  cf5c8d9f52807cb2d2f0a0ff54c478da              4
# 4  91383  cf5c8d9f52807cb2d2f0a0ff54c478da              5
# 5  91384  cf5c8d9f52807cb2d2f0a0ff54c478da              6
#
#                          product_id                         seller_id  \
# 0  064c975d37d3c646bd94d94c6e16f37e  a5ff20ff766e7f50bd5066f33da14413
# 1  7b44e5ea770ef06810f5df89006cc8b2  c003204e1ab016dfa150abc119207b24
# 2  58f579bb52bea63fe1c6c39c2d4272d8  a5ff20ff766e7f50bd5066f33da14413
# 3  64ec83de8f0026319c8829351e3d6e23  138dbe45fc62f1e244378131a6801526
# 4  24543438ec09114a42a153f76ae693f2  1fa2d3def6adfa70e58c276bb64fe5bb
# 5  a7bbff32c7321478b29f924301a1867d  dfc475d54e1b6dbeeb7d7d9bdaa63827
#
#    shipping_limit_date  price  freight_value
# 0  2018-08-28 13:24:27  17.99           9.00
# 1  2018-08-28 13:24:27  88.90           9.00
# 2  2018-08-28 13:24:27  18.60           9.00
# 3  2018-08-28 13:24:27  13.90           9.00
# 4  2018-08-30 13:24:27   6.90           9.00
# 5  2018-09-12 13:24:27  16.90           8.99

# %% [markdown]
# Another Late Delivery Date?
# (shipping_limit_date to carrier(Orders Table))

# %% [markdown]
# ### Final Query

# %%
query = """
SELECT 
order_id,
COUNT(DISTINCT(seller_id)) as sellers_per_orders,
COUNT(DISTINCT(product_id)) as product_per_orders,
MAX(shipping_limit_date) as shipping_limit,
AVG(price) AS avg_price,
AVG(freight_value) AS avg_freight
FROM OrderItem
GROUP BY order_id
;
"""
features_query['OrderItem'] = query
get_query(query)
# Out:
#                                order_id  sellers_per_orders  \
# 0      00010242fe8c5a6d1ba2dd792cb16214                   1
# 1      00018f77f2f0320c557190d7a144bdd3                   1
# 2      000229ec398224ef6ca0657da4fc703e                   1
# 3      00024acbcdf0a6daa1e931b038114c75                   1
# 4      00042b26cf59d7ce69dfabb4e55b4fd9                   1
# ...                                 ...                 ...
# 98661  fffc94f6ce00a00581880bf54a75a037                   1
# 98662  fffcd46ef2263f404302a634eb57f7eb                   1
# 98663  fffce4705a9662cd70adb13d4a31832d                   1
# 98664  fffe18544ffabc95dfada21779c9644f                   1
# 98665  fffe41c64501cc87c801fd61db3f6244                   1
#
#        product_per_orders       shipping_limit  avg_price  avg_freight
# 0                       1  2017-09-19 09:45:35      58.90        13.29
# 1                       1  2017-05-03 11:05:13     239.90        19.93
# 2                       1  2018-01-18 14:48:30     199.00        17.87
# 3                       1  2018-08-15 10:10:18      12.99        12.79
# 4                       1  2017-02-13 13:57:51     199.90        18.14
# ...                   ...                  ...        ...          ...
# 98661                   1  2018-05-02 04:11:01     299.99        43.41
# 98662                   1  2018-07-20 04:31:48     350.00        36.53
# 98663                   1  2017-10-30 17:14:25      99.90        16.95
# 98664                   1  2017-08-21 00:04:32      55.99         8.72
# 98665                   1  2018-06-12 17:10:13      43.00        12.79
#
# [98666 rows x 6 columns]

# %% [markdown]
# # Product

# %%
query = """
SELECT *
FROM Product;
"""
get_query(query)
# Out:
#        index                        product_id  \
# 0          0  1e9e8ef04dbcff4541ed26657ea517e5
# 1          1  3aa071139cb16b67ca9e5dea641aaa2f
# 2          2  96bd76ec8810374ed1b65e291975717f
# 3          3  cef67bcfe19066a932b7673e239eb23d
# 4          4  9dc1a7de274444849c219cff195d0b71
# ...      ...                               ...
# 32946  32946  a0b7d5a992ccda646f2d34e418fff5a0
# 32947  32947  bf4538d88321d0fd4412a93c974510e6
# 32948  32948  9a7c6041fa9592d9d9ef6cfe62a71f8c
# 32949  32949  83808703fc0706a22e264b9d75f04a2e
# 32950  32950  106392145fca363410d287a815be6de4
#
#                    product_category_name  product_name_lenght  \
# 0                             perfumaria                 40.0
# 1                                  artes                 44.0
# 2                          esporte_lazer                 46.0
# 3                                  bebes                 27.0
# 4                  utilidades_domesticas                 37.0
# ...                                  ...                  ...
# 32946                   moveis_decoracao                 45.0
# 32947  construcao_ferramentas_iluminacao                 41.0
# 32948                    cama_mesa_banho                 50.0
# 32949             informatica_acessorios                 60.0
# 32950                    cama_mesa_banho                 58.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                           287.0                 1.0             225.0
# 1                           276.0                 1.0            1000.0
# 2                           250.0                 1.0             154.0
# 3                           261.0                 1.0             371.0
# 4                           402.0                 4.0             625.0
# ...                           ...                 ...               ...
# 32946                        67.0                 2.0           12300.0
# 32947                       971.0                 1.0            1700.0
# 32948                       799.0                 1.0            1400.0
# 32949                       156.0                 2.0             700.0
# 32950                       309.0                 1.0            2083.0
#
#        product_length_cm  product_height_cm  product_width_cm
# 0                   16.0               10.0              14.0
# 1                   30.0               18.0              20.0
# 2                   18.0                9.0              15.0
# 3                   26.0                4.0              26.0
# 4                   20.0               17.0              13.0
# ...                  ...                ...               ...
# 32946               40.0               40.0              40.0
# 32947               16.0               19.0              16.0
# 32948               27.0                7.0              27.0
# 32949               31.0               13.0              20.0
# 32950               12.0                2.0               7.0
#
# [32951 rows x 10 columns]

# %% [markdown]
# ## Ideas
# 1. Identify the category of the most popular products in my store using the `product_category_name` information
# 2. Identify which products have the most complete and appealing descriptions to customers using the `product_name_lenght` and `product_description_length` information.
# 3. Identify which products have the most photos in my store using the information from `product_photos_qty`.
# 4. Understand the physical dimensions of the products in my store using the information from `product_weight_g`, `product_length_cm`, `product_height_cm` and `product_width_cm`.
# 5. Calculate the average price of products in each product category using the information from `product_category_name`.
# 6. Calculate the average weight of the products in each product category using the information from `product_category_name`.

# %% [markdown]
# ## `product_category_name`

# %%
query = """
SELECT product_category_name, COUNT(product_id) AS QTD
FROM Product
GROUP BY product_category_name
ORDER BY 2 DESC;
"""
get_query(query)
# Out:
#             product_category_name   QTD
# 0                 cama_mesa_banho  3029
# 1                   esporte_lazer  2867
# 2                moveis_decoracao  2657
# 3                    beleza_saude  2444
# 4           utilidades_domesticas  2335
# ..                            ...   ...
# 69  fashion_roupa_infanto_juvenil     5
# 70                casa_conforto_2     5
# 71                       pc_gamer     3
# 72             seguros_e_servicos     2
# 73              cds_dvds_musicais     1
#
# [74 rows x 2 columns]

# %% [markdown]
# ## Final Query

# %%
query = """
SELECT 
AVG(product_category_name) AS avg_category_name,
AVG(product_name_lenght) AS avg_name_lenght,
AVG(product_description_lenght) AS avg_description_name,
AVG(product_photos_qty) AS avg_photos_qty,
AVG(product_weight_g) AS avg_weight_g,
AVG(product_length_cm) AS  avg_length_cm,
AVG(product_height_cm) AS avg_height_cm,
AVG(product_width_cm) AS avg_width_cm

FROM Product;
"""
features_query['Product'] = query
get_query(query)
# Out:
#    avg_category_name  avg_name_lenght  avg_description_name  avg_photos_qty  \
# 0                0.0        48.476949            771.495285        2.188986
#
#    avg_weight_g  avg_length_cm  avg_height_cm  avg_width_cm
# 0   2276.472488      30.815078      16.937661     23.196728

# %% [markdown]
# # Product Translation

# %%
query = """
SELECT *
FROM products_cat_translated;
"""
get_query(query)
# Out:
#     index          product_category_name product_category_name_english
# 0       0                   beleza_saude                 health_beauty
# 1       1         informatica_acessorios         computers_accessories
# 2       2                     automotivo                          auto
# 3       3                cama_mesa_banho                bed_bath_table
# 4       4               moveis_decoracao               furniture_decor
# ..    ...                            ...                           ...
# 66     66                         flores                       flowers
# 67     67             artes_e_artesanato         arts_and_craftmanship
# 68     68                fraldas_higiene           diapers_and_hygiene
# 69     69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70     70             seguros_e_servicos         security_and_services
#
# [71 rows x 3 columns]

# %% [markdown]
# # Seller

# %%
query = """
SELECT *
FROM Seller;
"""
get_query(query)
# Out:
#       index                         seller_id  seller_zip_code_prefix  \
# 0         0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1         1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2         2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3         3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4         4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...     ...                               ...                     ...
# 3090   3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091   3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092   3092  74871d19219c7d518d0090283e03c137                    4650
# 3093   3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094   3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# 4     braganca paulista           SP
# ...                 ...          ...
# 3090            sarandi           PR
# 3091            palhoca           SC
# 3092          sao paulo           SP
# 3093            pelotas           RS
# 3094            taubate           SP
#
# [3095 rows x 5 columns]

# %% [markdown]
# ## Order quantity per seller

# %%
get_query(features_query['OrderItem']).head(1)
# Out:
#                            order_id  sellers_per_orders  product_per_orders  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                   1                   1
#
#         shipping_limit  avg_price  avg_freight
# 0  2017-09-19 09:45:35       58.9        13.29

# %%
query = """
SELECT i.seller_id,
s.seller_city,
s.seller_state,
COUNT(i.order_id),
SUM(i.price),
SUM(i.freight_value),
AVG(i.price),
AVG(i.freight_value),
SUM(p.payment_value),
AVG(p.payment_value)

FROM OrderItem as i
INNER JOIN Seller as s
ON i.seller_id = s.seller_id
INNER JOIN OrderPayment as p
ON p.order_id = i.order_id
GROUP BY i.seller_id
ORDER BY COUNT(i.order_id) DESC

;
"""
get_query(query)
# Out:
#                              seller_id            seller_city seller_state  \
# 0     4a3ca9315b744ce9f8e9374361493884               ibitinga           SP
# 1     6560211a19b47992c3666cc44a7e94c0              sao paulo           SP
# 2     1f50f920176fa81dab994f9023523100  sao jose do rio preto           SP
# 3     cc419e0650a3c5ba77189a1882b7556a            santo andre           SP
# 4     da8622b14eb17ae2831f4ac5b9dab84a             piracicaba           SP
# ...                                ...                    ...          ...
# 3090  04ee0ec01589969663ba5967c0e0bdc0                lajeado           RS
# 3091  00d8b143d12632bad99c0ad66ad52825         belo horizonte           MG
# 3092  00ab3eff1b5192e5f1a63bcecfee11c8              sao paulo           SP
# 3093  003554e2dce176b5555353e4f3555ac8                goiania           GO
# 3094  001e6ad469a905060d959994f1b41e4f            sao goncalo           RJ
#
#       COUNT(i.order_id)  SUM(i.price)  SUM(i.freight_value)  AVG(i.price)  \
# 0                  2133     213299.57              37335.72     99.999798
# 1                  2122     128489.82              29277.64     60.551282
# 2                  2008     111435.81              37274.85     55.495921
# 3                  1847     108439.73              26658.66     58.711278
# 4                  1639     169297.77              26453.28    103.293331
# ...                 ...           ...                   ...           ...
# 3090                  1        289.49                 24.83    289.490000
# 3091                  1         86.00                 51.10     86.000000
# 3092                  1         98.00                 12.08     98.000000
# 3093                  1        120.00                 19.38    120.000000
# 3094                  1        250.00                 17.94    250.000000
#
#       AVG(i.freight_value)  SUM(p.payment_value)  AVG(p.payment_value)
# 0                17.503854             301245.27            141.230788
# 1                13.797191             179657.75             84.664350
# 2                18.563172             290253.42            144.548516
# 3                14.433492             141309.58             76.507623
# 4                16.139890             272219.32            166.088664
# ...                    ...                   ...                   ...
# 3090             24.830000                314.32            314.320000
# 3091             51.100000                137.10            137.100000
# 3092             12.080000                110.08            110.080000
# 3093             19.380000                139.38            139.380000
# 3094             17.940000                267.94            267.940000
#
# [3095 rows x 10 columns]

# %% [markdown]
# ## Final Query

# %%
query = """
SELECT *
FROM Seller;
"""
features_query['Seller'] = query
get_query(query)
# Out:
#       index                         seller_id  seller_zip_code_prefix  \
# 0         0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1         1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2         2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3         3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4         4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...     ...                               ...                     ...
# 3090   3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091   3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092   3092  74871d19219c7d518d0090283e03c137                    4650
# 3093   3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094   3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# 4     braganca paulista           SP
# ...                 ...          ...
# 3090            sarandi           PR
# 3091            palhoca           SC
# 3092          sao paulo           SP
# 3093            pelotas           RS
# 3094            taubate           SP
#
# [3095 rows x 5 columns]

# %% [markdown]
# # Customer

# %%
query = """
SELECT *
FROM Customer;
"""
get_query(query)
# Out:
#        index                       customer_id  \
# 0          0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1          1  18955e83d337fd6b2def6b18a428ac77
# 2          2  4e7b3e00288586ebd08712fdd0374a03
# 3          3  b2b6027bc5c5109e529d4dc6358b12c3
# 4          4  4f2d8ab171c80ec8364f7c12e35b23ad
# ...      ...                               ...
# 99436  99436  17ddf5dd5d51696bb3d7c6291687be6f
# 99437  99437  e7b71a9017aa05c9a7fd292d714858e8
# 99438  99438  5e28dfe12db7fb50a4b2f691faecea5e
# 99439  99439  56b18e2166679b8a959d72dd06da27f9
# 99440  99440  274fa6071e5e17fe303b9748641082c8
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# 4      345ecd01c38d18a9036ed96c73b8d066                     13056
# ...                                 ...                       ...
# 99436  1a29b476fee25c95fbafc67c5ac95cf8                      3937
# 99437  d52a67c98be1cf6a5c84435bd38d095d                      6764
# 99438  e9f50caf99f032f0bf3c55141f019d99                     60115
# 99439  73c2643a0a458b49f58cea58833b192e                     92120
# 99440  84732c5050c01db9b23e19ba39899398                      6703
#
#                customer_city customer_state
# 0                     franca             SP
# 1      sao bernardo do campo             SP
# 2                  sao paulo             SP
# 3            mogi das cruzes             SP
# 4                   campinas             SP
# ...                      ...            ...
# 99436              sao paulo             SP
# 99437        taboao da serra             SP
# 99438              fortaleza             CE
# 99439                 canoas             RS
# 99440                  cotia             SP
#
# [99441 rows x 6 columns]

# %% [markdown]
# Strange how this customer_unique_id works, how many customer_id does each customer_unique_id have?

# %%
query = """
SELECT customer_unique_id, COUNT(customer_id) as count_customer
FROM Customer
GROUP BY customer_unique_id
HAVING count_customer > 1
ORDER BY count_customer DESC
;
"""
values = get_query(query)
values
# Out:
#                     customer_unique_id  count_customer
# 0     8d50f5eadf50201ccdcedfb9e2ac8455              17
# 1     3e43e6105506432c953e165fb2acf44c               9
# 2     ca77025e7201e3b30c44b472ff346268               7
# 3     6469f99c1f9dfae7733b25662e7f1782               7
# 4     1b6c7548a2a1f9037c1fd3ddfed95f33               7
# ...                                ...             ...
# 2992  00a39521eb40f7012db50455bf083460               2
# 2993  0058f300f57d7b93c477a131a59b36c3               2
# 2994  004b45ec5c64187465168251cd1c9c2f               2
# 2995  004288347e5e88a27ded2bb23747066c               2
# 2996  00172711b30d52eea8b313a7f2cced02               2
#
# [2997 rows x 2 columns]

# %% [markdown]
# So I can see the relationship of how many purchases a person made from this?
# Let's test

# %%
get_query(features_query['OrderItem']).head(1)
# Out:
#                            order_id  sellers_per_orders  product_per_orders  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                   1                   1
#
#         shipping_limit  avg_price  avg_freight
# 0  2017-09-19 09:45:35       58.9        13.29

# %%
query = """

SELECT 
  c.customer_unique_id , 
  COUNT(DISTINCT(c.customer_id)) ,
  COUNT(DISTINCT(o.order_id)) ,
  COUNT(DISTINCT(i.product_id)),
  MAX(order_purchase_timestamp)
  
FROM Customer AS c
INNER JOIN Orders AS o
  ON c.customer_id = o.customer_id
INNER JOIN OrderItem AS i
  ON o.order_id = i.order_id
GROUP BY c.customer_unique_id
HAVING COUNT(DISTINCT(i.product_id)) > 1
ORDER BY 3 DESC

;
"""
get_query(query)
# Out:
#                     customer_unique_id  COUNT(DISTINCT(c.customer_id))  \
# 0     8d50f5eadf50201ccdcedfb9e2ac8455                              16
# 1     3e43e6105506432c953e165fb2acf44c                               9
# 2     ca77025e7201e3b30c44b472ff346268                               7
# 3     6469f99c1f9dfae7733b25662e7f1782                               7
# 4     1b6c7548a2a1f9037c1fd3ddfed95f33                               7
# ...                                ...                             ...
# 5451  001928b561575b2821c92254a2327d06                               1
# 5452  001926cef41060fae572e2e7b30bd2a4                               1
# 5453  000fbf0473c10fc1ab6f8d2d286ce20c                               1
# 5454  000de6019bb59f34c099a907c151d855                               1
# 5455  00053a61a98854899e70ed204dd4bafe                               1
#
#       COUNT(DISTINCT(o.order_id))  COUNT(DISTINCT(i.product_id))  \
# 0                              16                             15
# 1                               9                             13
# 2                               7                              9
# 3                               7                              5
# 4                               7                              9
# ...                           ...                            ...
# 5451                            1                              2
# 5452                            1                              2
# 5453                            1                              2
# 5454                            1                              2
# 5455                            1                              2
#
#      MAX(order_purchase_timestamp)
# 0              2018-08-20 19:14:26
# 1              2018-02-27 18:36:39
# 2              2018-06-01 11:38:29
# 3              2018-06-28 00:43:34
# 4              2018-02-14 13:22:12
# ...                            ...
# 5451           2018-08-24 21:17:00
# 5452           2017-08-17 12:55:47
# 5453           2018-07-26 09:43:52
# 5454           2017-08-17 19:10:33
# 5455           2018-02-28 11:15:41
#
# [5456 rows x 5 columns]

# %% [markdown]
# It still seems like very small amounts, it's not possible that one person only made 16 purchases at most, that must be in relation to something else, I don't know

# %% [markdown]
# I can test if the address between a single `customer_unique_id`
# * Testing : `3e43e6105506432c953e165fb2acf44c`

# %%
query = """

SELECT *
FROM Customer
WHERE customer_unique_id == '3e43e6105506432c953e165fb2acf44c'
;
"""
get_query(query)
# Out:
#    index                       customer_id                customer_unique_id  \
# 0   5113  f37a14140ac3a8efbb4d2eab6585edb7  3e43e6105506432c953e165fb2acf44c
# 1   6129  a4413edae691fd0d28bd04b8a38b259d  3e43e6105506432c953e165fb2acf44c
# 2   8657  1815fdaaae692479110428598596b5e5  3e43e6105506432c953e165fb2acf44c
# 3  10685  e68e6423401e85c138229b23d4bf4761  3e43e6105506432c953e165fb2acf44c
# 4  20597  b63c9cfc5dcb06ed307ca95957fa216c  3e43e6105506432c953e165fb2acf44c
# 5  50029  2bbd32d4ef14893d2d8c1a0df08403cf  3e43e6105506432c953e165fb2acf44c
# 6  64987  b70f8552b91ef49129519206966e2472  3e43e6105506432c953e165fb2acf44c
# 7  89979  6b92dda6e324283dbe4969c443e3bf1a  3e43e6105506432c953e165fb2acf44c
# 8  90706  06ec7aed3161859018db02f695b6600d  3e43e6105506432c953e165fb2acf44c
#
#    customer_zip_code_prefix customer_city customer_state
# 0                     11701  praia grande             SP
# 1                     11700  praia grande             SP
# 2                     11701  praia grande             SP
# 3                     11700  praia grande             SP
# 4                     11704  praia grande             SP
# 5                     11701  praia grande             SP
# 6                     11700  praia grande             SP
# 7                     11701  praia grande             SP
# 8                     11701  praia grande             SP

# %% [markdown]
# From the cases that I have analyzed the change is usually in the customer_zip_code in small variations, so could it be address variations? It is not possible to conclude.

# %% [markdown]
# # Geolocation

# %%
query = """
SELECT *
FROM Geolocation;
"""
get_query(query)
# Out:
#            index  geolocation_zip_code_prefix  geolocation_lat  \
# 0              0                         1037       -23.545621
# 1              1                         1046       -23.546081
# 2              2                         1046       -23.546129
# 3              3                         1041       -23.544392
# 4              4                         1035       -23.541578
# ...          ...                          ...              ...
# 1000158  1000158                        99950       -28.068639
# 1000159  1000159                        99900       -27.877125
# 1000160  1000160                        99950       -28.071855
# 1000161  1000161                        99980       -28.388932
# 1000162  1000162                        99950       -28.070104
#
#          geolocation_lng geolocation_city geolocation_state
# 0             -46.639292        sao paulo                SP
# 1             -46.644820        sao paulo                SP
# 2             -46.642951        sao paulo                SP
# 3             -46.639499        sao paulo                SP
# 4             -46.641607        sao paulo                SP
# ...                  ...              ...               ...
# 1000158       -52.010705         tapejara                RS
# 1000159       -52.224882   getulio vargas                RS
# 1000160       -52.014716         tapejara                RS
# 1000161       -51.846871  david canabarro                RS
# 1000162       -52.018658         tapejara                RS
#
# [1000163 rows x 6 columns]

# %% [markdown]
# ## Difference in kilometers from seller to consumer

# %%
import time
start_time = time.time()
query = """

WITH Target AS(

SELECT 
	o.order_purchase_timestamp,
	i.order_id,
	i.order_item_id,
	i.product_id,
	i.seller_id,
	o.customer_id
FROM Orders AS o
INNER JOIN OrderItem AS i
	ON o.order_id = i.order_id
WHERE CAST(strftime('%Y',o.order_purchase_timestamp) AS int) >= 2018

), CustomerLoc AS(
SELECT
	c.customer_id,
	c.customer_zip_code_prefix,
	c.customer_city,
	c.customer_state
FROM Customer AS c
LEFT JOIN Target AS t
	ON c.customer_id = t.customer_id

), CustomerGeo AS (
SELECT 
	c.customer_id,
	c.customer_city,
	c.customer_state,
	AVG(g.geolocation_lat) AS c_lat,
	AVG(g.geolocation_lng) AS c_lng

FROM CustomerLoc AS c
LEFT JOIN Geolocation AS g
	ON  g.geolocation_state	= c.customer_state 
	AND g.geolocation_city	= c.customer_city 
	AND g.geolocation_zip_code_prefix = c.customer_zip_code_prefix
GROUP BY c.customer_id

), SellerLoc AS(

SELECT
  s.*
FROM Seller AS s
LEFT JOIN Target AS t
	ON s.seller_id = t.seller_id

), SellerGeo AS(

SELECT 
	s.seller_id,
	s.seller_city,
	s.seller_state,
	AVG(g.geolocation_lat) AS s_lat,
	AVG(g.geolocation_lng) AS s_lng

FROM SellerLoc AS s
LEFT JOIN Geolocation AS g
	ON  g.geolocation_state	= s.seller_state 
	AND g.geolocation_city	= s.seller_city 
	AND g.geolocation_zip_code_prefix = s.seller_zip_code_prefix
GROUP BY s.seller_id
)

SELECT 
--OrderInfo
t.order_purchase_timestamp,
t.order_id,
t.product_id,

--SellerInfo
t.seller_id,
s.seller_city,
s.seller_state,

--CustomerInfo
t.customer_id,
c.customer_city,
c.customer_state,

--GeoInfo
c.c_lat,
c.c_lng,
s.s_lat,
s.s_lng
--2 * 6371 * ASIN(SQRT(POWER(SIN(RADIANS((c.c_lat - s.s_lat) / 2)), 2) + COS(RADIANS(s.s_lat)) * COS(RADIANS(c.c_lat)) * POWER(SIN(RADIANS((c.c_lng - s.s_lng) / 2)), 2))) AS distance_km

FROM Target AS t
LEFT JOIN CustomerGeo AS c
ON t.customer_id = c.customer_id
LEFT JOIN SellerGeo AS s
ON t.seller_id = s.seller_id
ORDER BY t.order_purchase_timestamp DESC, t.order_id ASC, t.order_item_id ASC

;
"""
geo_loc = get_query(query)
finish = (time.time() - start_time) / 60
geo_loc
# Out:
#       order_purchase_timestamp                          order_id  \
# 0          2018-09-03 09:06:57  54282e97f61c23b78330c15b154c867d
# 1          2018-08-29 15:00:37  35a972d7f8436f405b56e36add1a7140
# 2          2018-08-29 14:52:00  03ef5dedbe7492bdae72eec50764c43f
# 3          2018-08-29 14:18:28  168626408cb32af0ffaf76711caae1dc
# 4          2018-08-29 14:18:23  0b223d92c27432930dfe407c6aea3041
# ...                        ...                               ...
# 61411      2018-01-01 10:24:03  7d0a0773edc4bdca0ef6ab55777718a7
# 61412      2018-01-01 09:36:21  67a98eaf984ba84c596f9f5456634f20
# 61413      2018-01-01 08:45:04  fbe41a4974e4a492e085d90e5be0b3e3
# 61414      2018-01-01 08:37:46  0462bad26ccfb8508951beb9ea398ae1
# 61415      2018-01-01 02:48:41  4f6daad34df49e10c8072b33faafcb2a
#
#                              product_id                         seller_id  \
# 0      b98992ea80b467987a7fbb88e7f2076a  25be943a321c8938947bdaabca979a90
# 1      d04857e7b4b708ee8b8b9921163edba3  9f505651f4a6abe901a56cdc21508025
# 2      c7f27c5bef2338541c772b5776403e6a  7d7866a99a8656a42c7ff6352a433410
# 3      bdcf6a834e8faa30dac3886c7a58e92e  2a84855fd20af891be03bc5924d2b453
# 4      2b4472df15512a2825ae86fd9ae79335  67bf6941ba2f1fa1d02c375766bc3e53
# ...                                 ...                               ...
# 61411  be5679ce5a2343c40455223d7bef6dfb  643214e62b870443ccbe55ab29a4dccf
# 61412  c4baedd846ed09b85f78a781b522f126  a1043bafd471dff536d0c462352beb48
# 61413  a096400f2b6fbe9c868f7dd5f1333e5a  cbd996ad3c1b7dc71fd0e5f5df9087e2
# 61414  d93d7e81a8d724c4ef661e75647cf325  5a93f3ab0ef4c84ed5e1b5dbf23978bc
# 61415  468a4d241243dd96169888c0ad022086  e067ad2c1c0b48758eb1b5228bcf7a68
#
#                  seller_city seller_state                       customer_id  \
# 0      sao bernardo do campo           SP  4b7decb9b58e2569548b8b4c8e20e8d7
# 1                  sao paulo           SP  898b7fee99c4e42170ab69ba59be0a8b
# 2                  sao paulo           SP  496630b6740bcca28fce9ba50d8a26ef
# 3             belo horizonte           MG  6e353700bc7bcdf6ebc15d6de16d7002
# 4                   curitiba           PR  e60df9449653a95af4549bbfcb18a6eb
# ...                      ...          ...                               ...
# 61411              sao paulo           SP  a5c957468ed6f0d66633b446e17e9865
# 61412               ilicinea           MG  b2706ca3ca9a2846e387cb6ed9e74c5a
# 61413  sao jose do rio preto           SP  3afe7d56a3df6e202fc6b851b1cfce3b
# 61414        monteiro lobato           SP  b1449a43a666cba48f485fff0a509b8e
# 61415                 santos           SP  73eb345e2b03af4125d07ca4a250d06a
#
#              customer_city customer_state      c_lat      c_lng      s_lat  \
# 0                sao paulo             SP -23.433561 -46.720966 -23.705946
# 1                  limeira             SP -22.560755 -47.446494 -23.590043
# 2       sao caetano do sul             SP -23.620298 -46.564185 -23.557985
# 3                 paracatu             MG -17.224179 -46.874265 -19.917826
# 4                 curitiba             PR -25.425730 -49.253916 -25.394747
# ...                    ...            ...        ...        ...        ...
# 61411            sao paulo             SP -23.444037 -46.727653 -23.498456
# 61412  valparaiso de goias             GO -16.088405 -47.987241 -20.940852
# 61413  sao jose dos campos             SP -23.185585 -45.871733 -20.845094
# 61414       afonso claudio             ES -20.075949 -41.123984 -22.953715
# 61415               maceio             AL  -9.653960 -35.757581 -23.969746
#
#            s_lng
# 0     -46.557000
# 1     -46.632541
# 2     -46.639339
# 3     -43.942418
# 4     -49.344438
# ...          ...
# 61411 -46.579465
# 61412 -45.827316
# 61413 -49.362879
# 61414 -45.839550
# 61415 -46.321939
#
# [61416 rows x 13 columns]

# %%
finish
# Out:
# 0.651405390103658

# %%
from geopy.distance import geodesic

# %%
geo_loc = geo_loc.fillna(0)

# %%
def distancer(row):
    coords_1 = (row['s_lat'], row['s_lng'])
    coords_2 = (row['c_lat'], row['c_lng'])
    return geodesic(coords_1, coords_2).km

geo_loc['distance_km'] = geo_loc.apply(distancer, axis=1)

# %%
geo_loc.drop(['c_lat', 'c_lng', 's_lat', 's_lng'], axis=1)
# Out:
#       order_purchase_timestamp                          order_id  \
# 0          2018-09-03 09:06:57  54282e97f61c23b78330c15b154c867d
# 1          2018-08-29 15:00:37  35a972d7f8436f405b56e36add1a7140
# 2          2018-08-29 14:52:00  03ef5dedbe7492bdae72eec50764c43f
# 3          2018-08-29 14:18:28  168626408cb32af0ffaf76711caae1dc
# 4          2018-08-29 14:18:23  0b223d92c27432930dfe407c6aea3041
# ...                        ...                               ...
# 61411      2018-01-01 10:24:03  7d0a0773edc4bdca0ef6ab55777718a7
# 61412      2018-01-01 09:36:21  67a98eaf984ba84c596f9f5456634f20
# 61413      2018-01-01 08:45:04  fbe41a4974e4a492e085d90e5be0b3e3
# 61414      2018-01-01 08:37:46  0462bad26ccfb8508951beb9ea398ae1
# 61415      2018-01-01 02:48:41  4f6daad34df49e10c8072b33faafcb2a
#
#                              product_id                         seller_id  \
# 0      b98992ea80b467987a7fbb88e7f2076a  25be943a321c8938947bdaabca979a90
# 1      d04857e7b4b708ee8b8b9921163edba3  9f505651f4a6abe901a56cdc21508025
# 2      c7f27c5bef2338541c772b5776403e6a  7d7866a99a8656a42c7ff6352a433410
# 3      bdcf6a834e8faa30dac3886c7a58e92e  2a84855fd20af891be03bc5924d2b453
# 4      2b4472df15512a2825ae86fd9ae79335  67bf6941ba2f1fa1d02c375766bc3e53
# ...                                 ...                               ...
# 61411  be5679ce5a2343c40455223d7bef6dfb  643214e62b870443ccbe55ab29a4dccf
# 61412  c4baedd846ed09b85f78a781b522f126  a1043bafd471dff536d0c462352beb48
# 61413  a096400f2b6fbe9c868f7dd5f1333e5a  cbd996ad3c1b7dc71fd0e5f5df9087e2
# 61414  d93d7e81a8d724c4ef661e75647cf325  5a93f3ab0ef4c84ed5e1b5dbf23978bc
# 61415  468a4d241243dd96169888c0ad022086  e067ad2c1c0b48758eb1b5228bcf7a68
#
#                  seller_city seller_state                       customer_id  \
# 0      sao bernardo do campo           SP  4b7decb9b58e2569548b8b4c8e20e8d7
# 1                  sao paulo           SP  898b7fee99c4e42170ab69ba59be0a8b
# 2                  sao paulo           SP  496630b6740bcca28fce9ba50d8a26ef
# 3             belo horizonte           MG  6e353700bc7bcdf6ebc15d6de16d7002
# 4                   curitiba           PR  e60df9449653a95af4549bbfcb18a6eb
# ...                      ...          ...                               ...
# 61411              sao paulo           SP  a5c957468ed6f0d66633b446e17e9865
# 61412               ilicinea           MG  b2706ca3ca9a2846e387cb6ed9e74c5a
# 61413  sao jose do rio preto           SP  3afe7d56a3df6e202fc6b851b1cfce3b
# 61414        monteiro lobato           SP  b1449a43a666cba48f485fff0a509b8e
# 61415                 santos           SP  73eb345e2b03af4125d07ca4a250d06a
#
#              customer_city customer_state  distance_km
# 0                sao paulo             SP    34.499938
# 1                  limeira             SP   141.240912
# 2       sao caetano do sul             SP    10.318630
# 3                 paracatu             MG   429.707391
# 4                 curitiba             PR     9.732819
# ...                    ...            ...          ...
# 61411            sao paulo             SP    16.294922
# 61412  valparaiso de goias             GO   583.484825
# 61413  sao jose dos campos             SP   443.923429
# 61414       afonso claudio             ES   583.221383
# 61415               maceio             AL  1941.526559
#
# [61416 rows x 10 columns]

# %% [markdown]
# I tested some distances and they are matching on google maps, but this analysis is not useful for us because we are not going to analyze each item but each order

# %% [markdown]
# # All Features Query

# %%
get_query(features_query['Orders']).head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-b1b6d73c2b4d> in <module>
# ----> 1 get_query(features_query['Orders']).head(1)
#
# KeyError: 'Orders'

# %%
query = """

WITH Location AS (
SELECT 
--OrderInfo
o.order_purchase_timestamp,
i.order_id,

--SellerInfo
s.seller_city,
s.seller_state,

--CustomerInfo
c.customer_city,
c.customer_state,

--Same?
CASE WHEN s.seller_city = c.customer_city AND s.seller_state = c.customer_state THEN 1 ELSE 0 END same_city,
CASE WHEN s.seller_state = c.customer_state THEN 1 ELSE 0 END same_state

FROM Orders AS o
INNER JOIN OrderItem AS i
  ON o.order_id = i.order_id
LEFT JOIN Customer AS c
  ON o.customer_id = c.customer_id
LEFT JOIN Seller AS s
  ON i.seller_id = s.seller_id
WHERE CAST(strftime('%Y',o.order_purchase_timestamp) AS int) >= 2018
ORDER BY o.order_purchase_timestamp DESC, i.order_id ASC, i.order_item_id ASC
)

SELECT 

--Orders
  o.order_id,
  o.order_status AS status,
  o.order_purchase_timestamp AS purchase,
  o.order_approved_at AS approved,
  o.order_delivered_carrier_date AS delivered_carrier,
  o.order_delivered_customer_date AS delivered_customer,
  o.order_estimated_delivery_date AS delivery_estimated,

--OrdersPayments
  CASE WHEN MAX(p.payment_sequential) = 1 THEN 0 ELSE 1 END AS has_sequential,
  CASE WHEN MAX(p.payment_installments) = 1 THEN 0 ELSE 1 END AS has_installments,
  MAX(p.payment_value) as last_payment,
  
--OrdersReview (Target)
  MAX(r.review_score) as score,

--OrdersItem
  COUNT(DISTINCT(i.seller_id)) as sellers_per_order,
  COUNT(DISTINCT(i.product_id)) as product_per_order,
  MAX(i.shipping_limit_date) as shipping_limit,
  AVG(i.price) AS avg_price,
  AVG(i.freight_value) AS avg_freight,

--Product
  AVG(pd.product_name_lenght) AS avg_name_lenght,
  AVG(pd.product_description_lenght) AS avg_description_name,
  AVG(pd.product_photos_qty) AS avg_photos_qty,
  AVG(pd.product_weight_g) AS avg_weight_g,
  AVG(pd.product_length_cm) AS  avg_length_cm,
  AVG(pd.product_height_cm) AS avg_height_cm,
  AVG(pd.product_width_cm) AS avg_width_cm,

--Seller Vs Customer (Location)
  AVG(same_city) AS avg_same_city,
  AVG(same_state) AS avg_same_state
  
FROM Orders AS o
LEFT JOIN OrderPayment AS p
ON p.order_id = o.order_id
LEFT JOIN OrderReview AS r
ON r.order_id = o.order_id
LEFT JOIN OrderItem AS i
ON i.order_id = o.order_id
LEFT JOIN Product AS pd
ON i.product_id = pd.product_id
LEFT JOIN Location AS l
ON o.order_id = l.order_id

WHERE CAST(strftime('%Y',o.order_purchase_timestamp) AS int) >= 2018
GROUP BY o.order_id
ORDER BY o.order_purchase_timestamp DESC

;
"""
df = get_query(query)
df.head()
# Out:
#                            order_id    status             purchase approved  \
# 0  10a045cdf6a5650c21e9cfeb60384c16  canceled  2018-10-17 17:30:18     None
# 1  b059ee4de278302d550a3035c4cdb740  canceled  2018-10-16 20:16:02     None
# 2  a2ac6dad85cf8af5b0afb510a240fe8c  canceled  2018-10-03 18:55:29     None
# 3  616fa7d4871b87832197b2a137a115d2  canceled  2018-10-01 15:30:09     None
# 4  392ed9afd714e3c74767d0c4d3e3f477  canceled  2018-09-29 09:13:03     None
#
#   delivered_carrier delivered_customer   delivery_estimated  has_sequential  \
# 0              None               None  2018-10-30 00:00:00               0
# 1              None               None  2018-11-12 00:00:00               0
# 2              None               None  2018-10-16 00:00:00               0
# 3              None               None  2018-10-23 00:00:00               0
# 4              None               None  2018-10-15 00:00:00               0
#
#    has_installments  last_payment  ...  avg_freight  avg_name_lenght  \
# 0                 0         89.71  ...          NaN              NaN
# 1                 0        222.03  ...          NaN              NaN
# 2                 0        197.55  ...          NaN              NaN
# 3                 0         80.38  ...          NaN              NaN
# 4                 0        137.03  ...          NaN              NaN
#
#    avg_description_name avg_photos_qty  avg_weight_g  avg_length_cm  \
# 0                   NaN            NaN           NaN            NaN
# 1                   NaN            NaN           NaN            NaN
# 2                   NaN            NaN           NaN            NaN
# 3                   NaN            NaN           NaN            NaN
# 4                   NaN            NaN           NaN            NaN
#
#    avg_height_cm  avg_width_cm  avg_same_city  avg_same_state
# 0            NaN           NaN            NaN             NaN
# 1            NaN           NaN            NaN             NaN
# 2            NaN           NaN            NaN             NaN
# 3            NaN           NaN            NaN             NaN
# 4            NaN           NaN            NaN             NaN
#
# [5 rows x 25 columns]

# %%
from google.colab import drive

drive.mount('/content/drive',force_remount=True)
path = f'/content/drive/MyDrive/Data Science/Projects/Olist/Output/Olist_features.csv'
df.to_csv(path, header=True)
# Out:
# Mounted at /content/drive
